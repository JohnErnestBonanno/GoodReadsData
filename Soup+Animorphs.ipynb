# %%
# imports
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
wiki = requests.get('https://en.wikipedia.org/wiki/List_of_Animorphs_books')

# %%
wiki.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(wiki.content,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Animorphs books - Wikipedia
#   </title>
#   <script>
# ...

# %%
table = soup.find(class_ = 'wikitable sortable nowraplinks')

# %%
table_header = test.find_all('th')

# %%
table_header
# Out:
# [<th scope="col">#
#  </th>, <th scope="col">Title
#  </th>, <th scope="col">First Published
#  </th>, <th scope="col">ISBN
#  </th>, <th scope="col">Ghostwriter
#  </th>, <th>Narrator
#  </th>]

# %%
#for each of the 6 table headers
#take its contents at index[0]
#andprint them

for x in table_header:
    data_table_headers = x.contents[0] # could maybe extract this even earlier using the list modificatoin
    print(data_table_headers)
# Out:
# #
#
# Title
#
# First Published
#
# ISBN
#
# Ghostwriter
#
# Narrator

# %%
headings_clean = []

for x in table_header:
    temp = x.contents[0] # could maybe extract this even earlier using the list modificatoin
    clean = temp.replace('\n','') #cleans the list as you pull it
    headings_clean.append(clean)

print(headings_clean)
# Out:
# ['#', 'Title', 'First Published', 'ISBN', 'Ghostwriter', 'Narrator']

# %%
#add items to a list
"""
title_header_list = []

for x in table_header:
    data_table_headers = x.contents[0] 
    title_header_list.append(data_table_headers)

print(title_header_list)
"""
# Out:
# ['#\n', 'Title\n', 'First Published\n', 'ISBN\n', 'Ghostwriter\n', 'Narrator\n']

# %%
#clean afterwards instead of as you pull it in

#https://stackoverflow.com/questions/52638661/how-to-modify-strings-in-a-list
#clean_list = [i.replace('\n','') for i in title_header_list]

# %%
table
# Out:
# <table class="wikitable sortable nowraplinks">
# <tbody><tr>
# <th scope="col">#
# </th>
# <th scope="col">Title
# </th>
# <th scope="col">First Published
# </th>
# <th scope="col">ISBN
# </th>
# <th scope="col">Ghostwriter
# </th>
# <th>Narrator
# </th></tr>
# <tr>
# <td>1</td>
# <td><i><a href="/wiki/The_Invasion_(novel)" title="The Invasion (novel)">The Invasion</a></i></td>
# <td>June 1996</td>
# ...

# %%
table_rows = table.find_all('tr')
table_rows

# %%
#looks like the cleanest thing I've done so far
for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    #row_clean = [i.replace("'",'') for i in row]
    print(row_clean)
    
    #clean = temp.replace('\n','') #cleans the list as you pull it
# Out:
# []
# ...

# %%
list_of_lists = []

#looks like the cleanest thing I've done so far
for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    list_of_lists.append(row)

# %%
for x in row:
    print(x)
# Out:
# 54
# The Beginning
# May 2001
# ISBN 0-439-11528-0
#
#
# Everyone

# %%
row
# Out:
# ['54',
#  'The Beginning',
#  'May 2001',
#  'ISBN\xa00-439-11528-0',
#  '\n',
#  'Everyone\n']

# %%
temp_row = []
for x in row:
    clean1 = x.replace('\n','')
    temp_row.append(clean1)

# %%
temp_row
# Out:
# ['54', 'The Beginning', 'May 2001', 'ISBN\xa00-439-11528-0', '', 'Everyone']

# %%
import urllib.parse

# %%
type(temp_row[3])
# Out:
# str

# %%
temp_row[3].replace("'\x'",'')
# Out:
#   File "<ipython-input-166-977a4388fd8f>", line 1
#     temp_row[3].replace("'\x'",'')
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 1-2: truncated \xXX escape

# %%
x = x.replace('\\xa','')

# %%
print('ISBN\\xa')
# Out:
# ISBN\xa

# %%
x
# Out:
# '\xa00-439-11528-0'

# %%
list_of_lists
# Out:
# [[],
#  ['1',
#   'The Invasion',
#   'June 1996',
# ...

# %%
df = pd.DataFrame(list_of_lists)
df.columns = headings_clean

# %%
df = df.drop(0)

# %%
df['ISBN'][df['Title'] == 'The Invasion']
# Out:
# 1    .mw-parser-output cite.citation{font-style:inh...
# Name: ISBN, dtype: object

# %%
df.drop[iloc(1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-96e8c261da2a> in <module>()
# ----> 1 df.drop[iloc(1)]
#
# NameError: name 'iloc' is not defined

# %%
# this works
df = pd.DataFrame(columns = headings_clean)

# %%
df
# Out:
# Empty DataFrame
# Columns: [#, Title, First Published, ISBN, Ghostwriter, Narrator]
# Index: []

# %%
empty_df.append(row)
# Out:
#                     0    # First Published Ghostwriter ISBN Narrator Title
# 0                  54  NaN             NaN         NaN  NaN      NaN   NaN
# 1       The Beginning  NaN             NaN         NaN  NaN      NaN   NaN
# 2            May 2001  NaN             NaN         NaN  NaN      NaN   NaN
# 3  ISBN 0-439-11528-0  NaN             NaN         NaN  NaN      NaN   NaN
# 4                  \n  NaN             NaN         NaN  NaN      NaN   NaN
# 5          Everyone\n  NaN             NaN         NaN  NaN      NaN   NaN

# %%
empty_df
# Out:
# Empty DataFrame
# Columns: [#, Title, First Published, ISBN, Ghostwriter, Narrator]
# Index: []
